# %%
from sqlalchemy import create_engine, MetaData

url ='/content/drive/MyDrive/Colab Notebooks/LlmaIndex/ecommerce.db'

engine = create_engine(f'sqlite:///{url}')

# %%
metadata_obj = MetaData()
metadata_obj.reflect(engine)
metadata_obj.tables.keys()
# Out:
# dict_keys(['Clientes', 'Fornecedores', 'Funcionarios'])

# %%
import pandas as pd

pd.read_sql_table('Clientes',engine)
# Out:
#     ID_Cliente                  Nome                      Email  \
# 0            1           lucas moura      lucas.moura@email.com
# 1            2         julia andrade    julia.andrade@email.com
# 2            3           rafael dias      rafael.dias@email.com
# 3            4           carla souza      carla.souza@email.com
# 4            5           felipe neto      felipe.neto@email.com
# ..         ...                   ...                        ...
# 95          96     ana luiza correia       heitor40@correia.net
# 96          97    augusto nascimento      luiz-fernando91@da.br
# 97          98        dr. caue pires  azevedomelissa@bol.com.br
# 98          99          livia novaes  caldeiramelissa@costa.com
# 99         100  joao felipe da costa  helenacardoso@hotmail.com
#
#                         Rua_Numero              Estado  Valor_gasto
# 0             sitio de cardoso, 49           sao paulo        29017
# 1      trecho mariane teixeira, 90           tocantins         7834
# 2             setor de duarte, 114             paraiba         4071
# 3      recanto ana livia lopes, 53                para        17512
# 4           jardim de monteiro, 11           sao paulo        24307
# ..                             ...                 ...          ...
# 95  passarela pedro das neves, 806                para         9550
# 96              nucleo teixeira, 1  mato grosso do sul        22149
# 97                 ladeira peixoto              parana        33236
# 98               travessa lima, 82               ceara        42653
# 99            viela de cardoso, 87             roraima        20962
#
# [100 rows x 6 columns]

# %%
pd.read_sql_table('Fornecedores',engine)
# Out:
#    ID_Fornecedores                       Nome           Contato     Telefone  \
# 0                1          technex solutions     lucas martins  11912345678
# 1                2            quantum devices  isabela oliveira  11923456789
# 2                3   innovatetech corporation    rafael pereira  11934567890
# 3                4  electrogadget innovations         ana silva  11945678901
# 4                5          nexustech systems     pedro almeida  11956789012
# 5                6   quantumware technologies     camila santos  11967890123
#
#                                 Email                        Rua  \
# 0           info@technexsolutions.com     rua das inovacoes, 123
# 1          contact@quantumdevices.net   avenida tecnologica, 456
# 2        support@innovatetechcorp.com  alameda do progresso, 789
# 3  sales@electrogadgetinnovations.com        rua eletronica, 234
# 4           info@nexustechsystems.com   travessa da conexao, 567
# 5       inquiries@quantumwaretech.com          rua quantica, 890
#
#                   Bairro       Cidade Estado       cep
# 0                 centro    sao paulo     sp   1000000
# 1          jardim futuro    guarulhos     sp  20000000
# 2   centro das inovacoes  santo andre     sp  30000000
# 3         vila progresso  sao caetano     sp  40000000
# 4  parque das maravilhas    sao paulo     sp  88000000
# 5       bairro techville    guarulhos     sp  90000000

# %%
pd.read_sql_table('Funcionarios',engine)
# Out:
#    ID_Funcionarios             Nome       Cargo DataContratacao    Telefone  \
# 0                1      carla souza      vendas      2022-03-15  1134567890
# 1                2      paulo silva      vendas      2022-05-10  1123456789
# 2                3      marta rocha    gerencia      2022-07-20  1145678901
# 3                4      sofia ramos     tecnico      2022-01-12  1198765432
# 4                5     joao pereira     estoque      2022-09-05  1123456789
# 5                6    talita borges  financeiro      2022-04-02  1156789012
# 6                7  larissa freitas      vendas      2023-01-10  1187654321
#
#                        Email                          Rua  \
# 0      carla.souza@email.com          rua das flores, 123
# 1      paulo.silva@email.com          avenida do sol, 456
# 2     marta.rochaa@email.com      praca da liberdade, 789
# 3      sofia.ramos@email.com   alameda dos pinheiros, 234
# 4     joao.pereira@email.com  travessa dos girassois, 567
# 5    talita.borges@email.com          rodovia do mar, 890
# 6  larissa.freitas@email.com      beco das estrelas, 1234
#
#                    Bairro     Cidade Estado       cep
# 0          vila esperanca  sao paulo     sp   1000001
# 1      jardim da harmonia  sao paulo     sp  20000001
# 2       parque dos sabias  sao paulo     sp   1000001
# 3  floresta dos pinheiros  sao paulo     sp  40000001
# 4                  centro  sao paulo     sp  20000001
# 5             nova aurora  sao paulo     sp  90000001
# 6                  centro  sao paulo     sp  20000001

# %% [markdown]
# ## Llama Index

# %%
# !pip install llama-index llama-index-llms-groq llama-index-experimental llama-index-embeddings-huggingface llama-index-postprocessor-cohere-rerank gradio

# %%
from google.colab import userdata
key=userdata.get('GROQ-API')

# %%
modelo="llama-3.3-70b-versatile"
modelo_hf_emb="BAAI/bge-m3"

# %%
from llama_index.core import Settings
from llama_index.llms.groq import Groq
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

Settings.llm = Groq(model=modelo, api_key = key)
Settings.embed_model = HuggingFaceEmbedding(model_name=modelo_hf_emb)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/15.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/444 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %%
from llama_index.core import SQLDatabase
from llama_index.core.objects import SQLTableNodeMapping

sql_database = SQLDatabase(engine)
table_node_map = SQLTableNodeMapping(sql_database)

# %%
from llama_index.core.objects import SQLTableSchema

table_schema_objs = []
for nome_tabelas in metadata_obj.tables.keys():
  table_schema_objs.append(SQLTableSchema(table_name=nome_tabelas))

# %%
from llama_index.core.objects import ObjectIndex
from llama_index.core import VectorStoreIndex

obj_index = ObjectIndex.from_objects(table_schema_objs, table_node_map, VectorStoreIndex)

# %%
obj_retriever = obj_index.as_retriever(similarity_top_k=1)

# %% [markdown]
# ### Consultando o banco de dados

# %%
from llama_index.core.indices.struct_store.sql_query import SQLTableRetrieverQueryEngine

query_engine = SQLTableRetrieverQueryEngine(sql_database, obj_retriever)

# %%
resposta = query_engine.query("Quais os estados mais frequentes na tabela de Clientes?")

# %%
print(resposta)
# Out:
# Os estados mais frequentes na tabela de Clientes são Parana e Para, ambos com 7 ocorrências. Em seguida, vêm Rondônia com 6 ocorrências, e vários estados com 5 ocorrências, incluindo Tocantins, Sergipe, Rio de Janeiro, Maranhão, Goiás, Ceará e Amapá. Esses resultados mostram a distribuição dos clientes por estado, com os dois primeiros estados tendo a maior frequência.

# %%
# resposta.metadata

# %%
resposta = query_engine.query("Quais os fornecedores localizados em São Paulo?")
print(resposta)
# Out:
# Não há fornecedores localizados em São Paulo. A busca não retornou resultados.

# %% [markdown]
# ### Contextualizando o modelo

# %%
llm = Groq(model=modelo, api_key= key)

# %%
def gerar_descricao_tabela(nome_tabela, df_amostra):
    prompt = f"""
    Analise a amostra da tabela '{nome_tabela}' abaixo e forneça uma curta e breve descrição do conteúdo dessa tabela.
    Informe até o máximo de 5 valores únicos de cada coluna.


    Amostra da Tabela:
    {df_amostra}

    Descrição:
    """

    resposta = llm.complete(prompt = prompt)

    return resposta.text

# %%
nomes_tabelas = metadata_obj.tables.keys()
dicionario_tabelas = {}

for nome_tabela in nomes_tabelas:
  df = pd.read_sql_table(nome_tabela, engine)
  df_amostra = df.head(5).to_string()

  descricao = gerar_descricao_tabela(nome_tabela, df_amostra)
  dicionario_tabelas[nome_tabela] = descricao
  print(f'Tabela: {nome_tabela}\n Descrição: {descricao}')
  print('-'*15)
# Out:
# Tabela: Clientes
#  Descrição: A tabela "Clientes" contém informações sobre os clientes de uma empresa. As colunas incluem:
#
# - **ID_Cliente**: Identificador único do cliente, com valores como 1, 2, 3, 4 e 5.
# - **Nome**: Nome do cliente, com valores como "lucas moura", "julia andrade", "rafael dias", "carla souza" e "felipe neto".
# - **Email**: Endereço de e-mail do cliente, com valores como "lucas.moura@email.com", "julia.andrade@email.com", "rafael.dias@email.com", "carla.souza@email.com" e "felipe.neto@email.com".
# - **Rua_Numero**: Endereço do cliente, com valores como "sitio de cardoso, 49", "trecho mariane teixeira, 90", "setor de duarte, 114", "recanto ana livia lopes, 53" e "jardim de monteiro, 11".
# - **Estado**: Estado onde o cliente reside, com valores como "sao paulo", "tocantins", "paraiba" e "para" (possivelmente um erro de digitação, que pode ser "pará" ou outro estado).
# - **Valor_gasto**: Valor total gasto pelo cliente, com valores como 29017, 7834, 4071, 17512 e 24307.
#
# Essa tabela parece conter informações básicas sobre os clientes, incluindo seus contatos, endereços e histórico de compras.
# ---------------
# Tabela: Fornecedores
#  Descrição: A tabela 'Fornecedores' contém informações sobre diferentes fornecedores. Abaixo está uma breve descrição do conteúdo da tabela, incluindo até 5 valores únicos de cada coluna:
#
# - **ID_Fornecedores**: Identificador único de cada fornecedor. Valores únicos: 1, 2, 3, 4, 5.
# - **Nome**: Nome do fornecedor. Valores únicos: technex solutions, quantum devices, innovatetech corporation, electrogadget innovations, nexustech systems.
# - **Contato**: Pessoa de contato no fornecedor. Valores únicos: lucas martins, isabela oliveira, rafael pereira, ana silva, pedro almeida.
# - **Telefone**: Número de telefone do fornecedor. Valores únicos: 11912345678, 11923456789, 11934567890, 11945678901, 11956789012.
# - **Email**: Endereço de e-mail do fornecedor. Valores únicos: info@technexsolutions.com, contact@quantumdevices.net, support@innovatetechcorp.com, sales@electrogadgetinnovations.com, info@nexustechsystems.com.
# - **Rua**: Endereço da rua do fornecedor. Valores únicos: rua das inovacoes, avenida tecnologica, alameda do progresso, rua eletronica, travessa da conexao.
# - **Bairro**: Bairro onde o fornecedor está localizado. Valores únicos: centro, jardim futuro, centro das inovacoes, vila progresso, parque das maravilhas.
# - **Cidade**: Cidade onde o fornecedor está localizado. Valores únicos: sao paulo, guarulhos, santo andre, sao caetano.
# - **Estado**: Estado onde o fornecedor está localizado. Valores únicos: sp.
# - **cep**: Código de endereçamento postal do fornecedor. Valores únicos: 1000000, 20000000, 30000000, 40000000, 88000000.
#
# Essa tabela parece conter informações básicas sobre os fornecedores, incluindo detalhes de contato e endereço, o que pode ser útil para gerenciar relacionamentos com fornecedores em um contexto empresarial.
# ---------------
# Tabela: Funcionarios
#  Descrição: A tabela 'Funcionarios' contém informações sobre os funcionários de uma empresa. Abaixo está uma breve descrição do conteúdo de cada coluna, juntamente com até 5 valores únicos:
#
# 1. **ID_Funcionarios**: Identificador único de cada funcionário.
#    - Valores únicos: 1, 2, 3, 4, 5
#
# 2. **Nome**: Nome completo do funcionário.
#    - Valores únicos: carla souza, paulo silva, marta rocha, sofia ramos, joao pereira
#
# 3. **Cargo**: Cargo ou função que o funcionário ocupa na empresa.
#    - Valores únicos: vendas, gerencia, tecnico, estoque
#
# 4. **DataContratacao**: Data em que o funcionário foi contratado.
#    - Valores únicos: 2022-03-15, 2022-05-10, 2022-07-20, 2022-01-12, 2022-09-05
#
# 5. **Telefone**: Número de telefone do funcionário.
#    - Valores únicos: 1134567890, 1123456789, 1145678901, 1198765432
#
# 6. **Email**: Endereço de e-mail do funcionário.
#    - Valores únicos: carla.souza@email.com, paulo.silva@email.com, marta.rochaa@email.com, sofia.ramos@email.com, joao.pereira@email.com
#
# 7. **Rua**: Nome da rua onde o funcionário reside.
#    - Valores únicos: rua das flores, avenida do sol, praca da liberdade, alameda dos pinheiros, travessa dos girassois
#
# 8. **Bairro**: Bairro onde o funcionário reside.
#    - Valores únicos: vila esperanca, jardim da harmonia, parque dos sabias, floresta dos pinheiros, centro
#
# 9. **Cidade**: Cidade onde o funcionário reside.
#    - Valores únicos: sao paulo
#
# 10. **Estado**: Estado onde o funcionário reside.
#     - Valores únicos: sp
#
# 11. **cep**: Código de endereçamento postal do funcionário.
#     - Valores únicos: 1000001, 20000001, 40000001
#
# Essa tabela parece conter informações básicas sobre os funcionários, incluindo detalhes de contato, endereço e cargo na empresa.
# ---------------

# %%
table_schema_objs = [
    SQLTableSchema(table_name=nome_tabela, context_str= dicionario_tabelas[nome_tabela])
    for nome_tabela in nomes_tabelas
]

# %%
obj_index = ObjectIndex.from_objects(table_schema_objs, table_node_map, VectorStoreIndex)
obj_retriever = obj_index.as_retriever(similarity_top_k=1)

# %%
query_engine_2 = SQLTableRetrieverQueryEngine(sql_database, obj_retriever)

# %%
resposta = query_engine_2.query("Quais as fornecedoras localizadas na cidade de São Paulo?")
print(resposta)
# Out:
# As fornecedoras localizadas na cidade de São Paulo são:
#
# 1. Technex Solutions, localizada na Rua das Inovações, 123, no bairro do Centro.
# 2. Nexustech Systems, localizada na Travessa da Conexão, 567, no bairro do Parque das Maravilhas.
#
# Essas são as duas fornecedoras encontradas na cidade de São Paulo de acordo com os registros disponíveis.

# %%
resposta = query_engine_2.query("Qual a quantidade de funcionários cadastrados como vendedores?")
print(resposta)
# Out:
# Existem 3 funcionários cadastrados como vendedores.

# %% [markdown]
# ## 1º Prompt

# %%
from llama_index.core.prompts.default_prompts import DEFAULT_TEXT_TO_SQL_PROMPT
print(DEFAULT_TEXT_TO_SQL_PROMPT.template)
# Out:
# Given an input question, first create a syntactically correct {dialect} query to run, then look at the results of the query and return the answer. You can order the results by a relevant column to return the most interesting examples in the database.
#
# Never query for all the columns from a specific table, only ask for a few relevant columns given the question.
#
# Pay attention to use only the column names that you can see in the schema description. Be careful to not query for columns that do not exist. Pay attention to which column is in which table. Also, qualify column names with the table name when needed. You are required to use the following format, each taking one line:
#
# Question: Question here
# SQLQuery: SQL Query to run
# SQLResult: Result of the SQLQuery
# Answer: Final answer here
#
# Only use tables listed below.
# {schema}
#
# Question: {query_str}
# SQLQuery:

# %%
texto2sql = """Dada uma pergunta em linguagem natural, crie uma consulta {dialect} sintaticamente correta para executar e, em seguida, verifique os resultados da consulta e retorne a resposta. Você pode ordenar os resultados por uma coluna relevante para retornar os exemplos mais informativos no banco de dados.

Nunca consulte todas as colunas de uma tabela específica. Pergunte apenas por algumas colunas relevantes, de acordo com a pergunta.

Preste atenção para usar apenas os nomes de colunas que você pode ver na descrição do esquema. Tenha cuidado para não consultar colunas que não existem. Preste atenção em qual coluna está em qual tabela. Além disso, qualifique os nomes das colunas com o nome da tabela quando necessário.

Use o seguinte formato, cada um em uma linha:

Pergunta: Pergunta aqui
ConsultaSQL: Consulta SQL para executar
ResultadoSQL: Resultado da ConsultaSQL
Resposta: Resposta final aqui

Use apenas as tabelas listadas abaixo.

{schema}

Pergunta: {pergunta_user}
ConsultaSQL:
"""

# %%
from llama_index.core import PromptTemplate
prompt_1 = PromptTemplate(texto2sql, dialect = engine.dialect.name)
print(prompt_1.template)
# Out:
# Dada uma pergunta em linguagem natural, crie uma consulta {dialect} sintaticamente correta para executar e, em seguida, verifique os resultados da consulta e retorne a resposta. Você pode ordenar os resultados por uma coluna relevante para retornar os exemplos mais informativos no banco de dados.
#
# Nunca consulte todas as colunas de uma tabela específica. Pergunte apenas por algumas colunas relevantes, de acordo com a pergunta.
#
# Preste atenção para usar apenas os nomes de colunas que você pode ver na descrição do esquema. Tenha cuidado para não consultar colunas que não existem. Preste atenção em qual coluna está em qual tabela. Além disso, qualifique os nomes das colunas com o nome da tabela quando necessário.
#
# Use o seguinte formato, cada um em uma linha:
#
# Pergunta: Pergunta aqui
# ConsultaSQL: Consulta SQL para executar
# ResultadoSQL: Resultado da ConsultaSQL
# Resposta: Resposta final aqui
#
# Use apenas as tabelas listadas abaixo.
#
# {schema}
#
# Pergunta: {pergunta_user}
# ConsultaSQL:

# %% [markdown]
# ## Descrição tabelas

# %%
from typing import List

def descricao_tabela(schema_tabelas: List[SQLTableSchema]):
  descricao_str = []
  for tabela_schema in schema_tabelas:
    info_tabela = sql_database.get_single_table_info(tabela_schema.table_name)
    info_tabela += (' A descrição da tabela é: '+tabela_schema.context_str)

    descricao_str.append(info_tabela)
  return '\n\n'.join(descricao_str)

# %%
from llama_index.core.query_pipeline import FnComponent

contexto_tabela = FnComponent(fn=descricao_tabela)

# %% [markdown]
# ## Consulta SQL

# %%
from llama_index.core.llms import ChatResponse

def resposta_sql (resposta: ChatResponse) -> str:
  conteudo_resposta = resposta.message.content

  sql_consulta = conteudo_resposta.split("ConsultaSQL: ", 1)[-1].split("ResultadoSQL: ", 1)[0]
  return sql_consulta.strip().strip('```').strip()

# %%
consulta_sql = FnComponent(fn=resposta_sql)

# %%
from llama_index.core.retrievers import SQLRetriever

resultado_sql = SQLRetriever(sql_database)

# %%
prompt_2_str = '''
    Você é o "Assistente de consulta de banco de dados da Zoop".
    Dada a seguinte pergunta, a consulta SQL correspondente e o resultado SQL, responda à pergunta de modo agradável e objetivamente.
    Evite iniciar conversas com cumprimentos e apresentações, como "Olá".

    Pergunta: {pergunta_user}
    Consulta SQL: {consulta}
    Resultado SQL: {resultado}
    Resposta:
    '''

prompt_2 = PromptTemplate(
    prompt_2_str,
)

# %%
from llama_index.core.query_pipeline import QueryPipeline, InputComponent

qp = QueryPipeline(
    modules = {
        'entrada': InputComponent(),
        'acesso_tabela': obj_retriever,
        'contexto_tabela': contexto_tabela,
        'prompt_1': prompt_1,
        'llm_1': llm,
        'consulta_sql': consulta_sql,
        'resultado_sql': resultado_sql,
        'prompt_2': prompt_2,
        'llm_2': llm,
    },
    verbose=False
)

# %%
qp.add_chain(['entrada', 'acesso_tabela', 'contexto_tabela'])
qp.add_link('entrada', 'prompt_1', dest_key='pergunta_user')
qp.add_link('contexto_tabela', 'prompt_1', dest_key='schema')
qp.add_chain(['prompt_1', 'llm_1', 'consulta_sql', 'resultado_sql'])
qp.add_link('entrada', 'prompt_2', dest_key='pergunta_user')
qp.add_link('consulta_sql', 'prompt_2', dest_key= 'consulta')
qp.add_link('resultado_sql', 'prompt_2', dest_key='resultado')
qp.add_link('prompt_2', 'llm_2')

# %% [markdown]
# ## Testando as saídas

# %%
resposta = qp.run(query='Quais os estados mais frequentes na tabela Clientes?')
print(str(resposta))
# Out:
# > Running module entrada with input:
# query: Quais os estados mais frequentes na tabela Clientes?
#
# > Running module acesso_tabela with input:
# input: Quais os estados mais frequentes na tabela Clientes?
#
# > Running module contexto_tabela with input:
# schema_tabelas: [SQLTableSchema(table_name='Clientes', context_str='A tabela "Clientes" contém informações sobre os clientes de uma empresa. As colunas incluem:\n\n- **ID_Cliente**: Identificador único do cliente, co...
#
# > Running module prompt_1 with input:
# pergunta_user: Quais os estados mais frequentes na tabela Clientes?
# schema: Table 'Clientes' has columns: ID_Cliente (BIGINT), Nome (TEXT), Email (TEXT), Rua_Numero (TEXT), Estado (TEXT), Valor_gasto (BIGINT), . A descrição da tabela é: A tabela "Clientes" contém informações ...
#
# > Running module llm_1 with input:
# messages: Dada uma pergunta em linguagem natural, crie uma consulta sqlite sintaticamente correta para executar e, em seguida, verifique os resultados da consulta e retorne a resposta. Você pode ordenar os resu...
#
# > Running module consulta_sql with input:
# resposta: assistant: Pergunta: Quais os estados mais frequentes na tabela Clientes?
# ConsultaSQL: SELECT Estado, COUNT(Estado) AS Frequencia FROM Clientes GROUP BY Estado ORDER BY Frequencia DESC;
# ResultadoSQL: ...
#
# > Running module resultado_sql with input:
# input: SELECT Estado, COUNT(Estado) AS Frequencia FROM Clientes GROUP BY Estado ORDER BY Frequencia DESC;
#
# > Running module prompt_2 with input:
# pergunta_user: Quais os estados mais frequentes na tabela Clientes?
# consulta: SELECT Estado, COUNT(Estado) AS Frequencia FROM Clientes GROUP BY Estado ORDER BY Frequencia DESC;
# resultado: [NodeWithScore(node=TextNode(id_='0d5d4222-c2c9-4e94-874f-504b1842b986', embedding=None, metadata={'sql_query': 'SELECT Estado, COUNT(Estado) AS Frequencia FROM Clientes GROUP BY Estado ORDER BY Frequ...
#
# > Running module llm_2 with input:
# messages:
#     Você é o "Assistente de consulta de banco de dados da Zoop".
#     Dada a seguinte pergunta, a consulta SQL correspondente e o resultado SQL, responda à pergunta de modo agradável e objetivamente.
# ...
#
# assistant: Os estados mais frequentes na tabela Clientes são "Paraná" e "Pará", ambos com 7 ocorrências. Em seguida, aparece "Rondônia" com 6 ocorrências. Os estados "Tocantins", "Sergipe", "Rio de Janeiro", "Maranhão", "Goiás" e "Ceará" têm 5 ocorrências cada. Já "Amapá" também tem 5 ocorrências. Os demais estados têm frequências menores, variando de 4 a 1 ocorrência.

# %%
def entrada_saida (msg_user: str):
  saida = qp.run(query=msg_user)
  return str(saida.message.content)

# %%
def adicao_historico(msg_user, historico):
  msg_assistente = entrada_saida(msg_user)

  historico.append([msg_user, msg_assistente])
  return msg_assistente, historico

# %%
import gradio as gr

# %%
with gr.Blocks() as demo:
    gr.Markdown('## Chat com Assistente SQL')
    gr.Markdown(
        '''
        Este é um assistente SQL interativo, projetado para responder perguntas sobre os dados da loja Zoop.
        Insira sua pergunta no campo abaixo e o assistente irá responder com base no resultado da consulta SQL
        nos dados disponíveis.
        '''
    )
    chatbot = gr.Chatbot(label='Chat com Assistente')
    msg = gr.Textbox(label='Digite a sua pergunta e tecle Enter para enviar',
                     placeholder='Digite o texto aqui.')
    limpeza = gr.Button('Limpar a conversa')
    def atualizar_historico(msg_user, historico):
      msg_assistente, historico = adicao_historico(msg_user, historico)
      return '', historico
    msg.submit(atualizar_historico, inputs=[msg, chatbot], outputs=[msg, chatbot], queue=False)
    limpeza.click(lambda: None, inputs=None, outputs=chatbot, queue=False)

demo.queue()
demo.launch(debug=True)
# Out:
# <ipython-input-65-47d2970b0564>:10: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(label='Chat com Assistente')
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://d7397cb45b3a274015.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://d7397cb45b3a274015.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://d7397cb45b3a274015.gradio.live
